# %%
import pandas as pd
import numpy as np
import tensorflow 
import matplotlib.pyplot as plt
from keras.datasets import cifar10
(X_train,y_train ),(X_test,y_test) = cifar10.load_data()

# %% [markdown]
# Contntiene 60000 imagenes en color de 32x32 en 10 clases diferntes, 6000 por clase
#
# Aviones <br>
# Automoviles <br>
# Pajaros <br>
# Gatos <br>
# Ciervos <br>
# Perros <br>
# Ranas <br>
# Caballos <br>
# BArcos <br>
# Camiones

# %%
# Vemos el tamaño del dataset. Efectivamente tenemos 60000 filas de datos
print((len(X_train), len(X_test)),(len(y_train),len(y_test)))
# Out:
# (50000, 10000) (50000, 10000)

# %%
# Mostramos las primeras filas 
X_train
# Out:
# array([[[[ 59,  62,  63],
#          [ 43,  46,  45],
#          [ 50,  48,  43],
#          ...,
#          [158, 132, 108],
#          [152, 125, 102],
#          [148, 124, 103]],
#
#         [[ 16,  20,  20],
#          [  0,   0,   0],
#          [ 18,   8,   0],
#          ...,
#          [123,  88,  55],
#          [119,  83,  50],
#          [122,  87,  57]],
#
#         [[ 25,  24,  21],
#          [ 16,   7,   0],
#          [ 49,  27,   8],
#          ...,
#          [118,  84,  50],
#          [120,  84,  50],
#          [109,  73,  42]],
#
#         ...,
#
#         [[208, 170,  96],
#          [201, 153,  34],
#          [198, 161,  26],
#          ...,
#          [160, 133,  70],
#          [ 56,  31,   7],
#          [ 53,  34,  20]],
#
#         [[180, 139,  96],
#          [173, 123,  42],
#          [186, 144,  30],
#          ...,
#          [184, 148,  94],
#          [ 97,  62,  34],
#          [ 83,  53,  34]],
#
#         [[177, 144, 116],
# ...

# %%
# Con estas líneas comprobare si tengo datos Vacios en todas mis variables
for i in  X_train:
    if i is None:
        print("error X_train",i)
for i in  X_test:
    if i is None:
        print("error X_test",i)
for i in  y_train:
    if i is None:
        print("error y_train",i)
for i in  y_test:
    if i is None:
        print("error y_test",i)

# Efectivamente no tenemos nulos, podemos seguir

# %% [markdown]
# # Estadísticas Descriptivas

# %%
print("La Media en X_train es de: ",np.mean(X_train))
print("La Media en X_test es de: ",np.mean(X_test))
print("La Media en y_train es de: ",np.mean(y_train))
print("La Media en y_test es de: ",np.mean(y_test))
# Out:
# La Media en X_train es de:  120.70756512369792
# La Media en X_test es de:  121.52915475260417
# La Media en y_train es de:  4.5
# La Media en y_test es de:  4.5

# %%
print("La Mediana en X_train es de: ",np.median(X_train))
print("La Mediana en X_test es de: ",np.median(X_test))
print("La Mediana en y_train es de: ",np.median(y_train))
print("La Mediana en y_test es de: ",np.median(y_test))
# Out:
# La Mediana en X_train es de:  117.0
# La Mediana en X_test es de:  117.0
# La Mediana en y_train es de:  4.5
# La Mediana en y_test es de:  4.5

# %%
print("La Varianza en X_train es de: ",np.var(X_train))
print("La Varianza en X_test es de: ",np.var(X_test))
print("La Varianza en y_train es de: ",np.var(y_train))
print("La Varianza en y_test es de: ",np.var(y_test))
# Out:
# La Varianza en X_train es de:  4115.232236836622
# La Varianza en X_test es de:  4103.807893099353
# La Varianza en y_train es de:  8.25
# La Varianza en y_test es de:  8.25

# %%
print("La Maxima en X_train es de: ",np.max(X_train))
print("La Maxima en X_test es de: ",np.max(X_test))
print("La Maxima en y_train es de: ",np.max(y_train))
print("La Maxima en y_test es de: ",np.max(y_test))
print()
print("La Minima en X_train es de: ",np.min(X_train))
print("La Minima en X_test es de: ",np.min(X_test))
print("La Minima en y_train es de: ",np.min(y_train))
print("La Minima en y_test es de: ",np.min(y_test))
# Out:
# La Maxima en X_train es de:  255
# La Maxima en X_test es de:  255
# La Maxima en y_train es de:  9
# La Maxima en y_test es de:  9
#
# La Minima en X_train es de:  0
# La Minima en X_test es de:  0
# La Minima en y_train es de:  0
# La Minima en y_test es de:  0

# %%
print("La STD en X_train es de: ",np.std(X_train))
print("La STD en X_test es de: ",np.std(X_test))
print("La STD en y_train es de: ",np.std(y_train))
print("La STD en y_test es de: ",np.std(y_test))
# Out:
# La STD en X_train es de:  64.1500758911213
# La STD en X_test es de:  64.06097012299574
# La STD en y_train es de:  2.8722813232690143
# La STD en y_test es de:  2.8722813232690143

# %%
# Vemos una imagen
plt.imshow(X_train[0],cmap="gray")

# %%
plt.imshow(X_test[0],cmap="gray")

# %%
y_train[0]
# Out:
# array([6], dtype=uint8)

# %%
y_test[0]
# Out:
# array([3], dtype=uint8)

# %% [markdown]
# # Procesamiento de datos

# %%
X_test = X_test / 255
X_train = X_train / 255

# %%
lista = []
for i in y_train:
    if i not in lista:
        print(i[0])
        lista.append(i)
# Out:
# 6
# 9
# 4
# 1
# 2
# 7
# 8
# 3
# 5
# 0

# %%
lista = []
for i in y_test:
    if i not in lista:
        print(i[0])
        lista.append(i)
# Out:
# 3
# 8
# 0
# 6
# 1
# 9
# 5
# 7
# 4
# 2

# %%
# Veo que no tengo las variables de manera categorica, voy a aplicar LabelEncoder -> Este no guarda una relación entre las columnas. Por ello no utilizo OneHotEncoding, está si la guarda.
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()

y_train = lb.fit_transform(y_train)
y_test = lb.fit_transform(y_test)
# Out:
# C:\Users\Edwar\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Edwar\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn.model_selection import train_test_split

# Separamos nuestros datos de Entreno también en datos de Validación
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2)

print('Entrada entrenamiento: ', X_train.shape)
print('Salida entrenamiento: ', y_train.shape)
print()
print('Entrada test: ', X_test.shape)
print('Salida test: ', y_test.shape)
print()
print('Entrada validación: ', X_val.shape)
print('Salida validación: ', y_val.shape)
# Out:
# Entrada entrenamiento:  (40000, 32, 32, 3)
# Salida entrenamiento:  (40000,)
#
# Entrada test:  (10000, 32, 32, 3)
# Salida test:  (10000,)
#
# Entrada validación:  (10000, 32, 32, 3)
# Salida validación:  (10000,)

# %% [markdown]
# # Construcción y entrenamiento del modelo

# %%
import keras

# %%
import tensorflow as tf
from tensorflow import keras
from keras.applications import DenseNet121
from keras.models import Model, load_model
from keras.initializers import glorot_uniform
from keras.utils import plot_model
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
from IPython.display import display
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import *
from keras import backend as K
from keras import optimizers
import pandas as pd
import numpy as np
import os
import PIL
import seaborn as sns
import pickle
from PIL import Image
import cv2

# %%
def res_block(X, filter, stage):

  # Bloque Convolucional
  X_copy = X

  f1 , f2, f3 = filter

  # Camino Principal
  X = Conv2D(f1, (1,1),strides = (1,1), name ='res_'+str(stage)+'_conv_a', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = MaxPool2D((2,2))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_conv_a')(X)
  X = Activation('relu')(X)

  X = Conv2D(f2, kernel_size = (3,3), strides =(1,1), padding = 'same', name ='res_'+str(stage)+'_conv_b', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_conv_b')(X)
  X = Activation('relu')(X)

  X = Conv2D(f3, kernel_size = (1,1), strides =(1,1),name ='res_'+str(stage)+'_conv_c', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_conv_c')(X)


  # Camino Corto
  X_copy = Conv2D(f3, kernel_size = (1,1), strides =(1,1),name ='res_'+str(stage)+'_conv_copy', kernel_initializer= glorot_uniform(seed = 0))(X_copy)
  X_copy = MaxPool2D((2,2))(X_copy)
  X_copy = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_conv_copy')(X_copy)

  # Añadir
  X = Add()([X,X_copy])
  X = Activation('relu')(X)

  # Bloque de Identidad 1
  X_copy = X


  # Camino Principal
  X = Conv2D(f1, (1,1),strides = (1,1), name ='res_'+str(stage)+'_identity_1_a', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_1_a')(X)
  X = Activation('relu')(X)

  X = Conv2D(f2, kernel_size = (3,3), strides =(1,1), padding = 'same', name ='res_'+str(stage)+'_identity_1_b', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_1_b')(X)
  X = Activation('relu')(X)

  X = Conv2D(f3, kernel_size = (1,1), strides =(1,1),name ='res_'+str(stage)+'_identity_1_c', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_1_c')(X)

  # Añadir
  X = Add()([X,X_copy])
  X = Activation('relu')(X)

  # Bloque de Identidad 2
  X_copy = X


  # Camino Principal
  X = Conv2D(f1, (1,1),strides = (1,1), name ='res_'+str(stage)+'_identity_2_a', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_2_a')(X)
  X = Activation('relu')(X)

  X = Conv2D(f2, kernel_size = (3,3), strides =(1,1), padding = 'same', name ='res_'+str(stage)+'_identity_2_b', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_2_b')(X)
  X = Activation('relu')(X)

  X = Conv2D(f3, kernel_size = (1,1), strides =(1,1),name ='res_'+str(stage)+'_identity_2_c', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_2_c')(X)

  # Añadir
  X = Add()([X,X_copy])
  X = Activation('relu')(X)

  return X

# %%
input_shape = (32, 32, 3)

# Tamaño del tensor de entrada
X_input = Input(input_shape)
print(X_input)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 32, 32, 3), dtype=tf.float32, name='input_4'), name='input_4', description="created by layer 'input_4'")

# %%
# Zero-padding
X = ZeroPadding2D((3,3))(X_input)

# 1 - Fase
X = Conv2D(64, (7,7), strides= (2,2), name = 'conv1', kernel_initializer= glorot_uniform(seed = 0))(X)
X = BatchNormalization(axis =3, name = 'bn_conv1')(X)
X = Activation('relu')(X)
X = MaxPooling2D((3,3), strides= (2,2))(X)

# 2 - Fase
X = res_block(X, filter= [64,64,256], stage= 2)

# 3 - Fase
X = res_block(X, filter= [128,128,512], stage= 3)

# 4 - Fase
# X = res_block(X, filter= [256,256,1024], stage= 4)

# # 5 - Fase
# X = res_block(X, filter= [512,512,2048], stage= 5)

# Average Pooling
X = AveragePooling2D((1,1), name = 'Averagea_Pooling')(X)

# Capa Final
X = Flatten()(X)
X = Dense(4096, activation = 'relu')(X)
X = Dropout(0.3)(X)
X = Dense(2048, activation = 'relu')(X)
X = Dropout(0.2)(X)
X = Dense(1024, activation = 'relu')(X)
X = Dropout(0.1)(X)
X = Dense(10, activation = 'softmax')(X)


modelo = Model( inputs= X_input, outputs = X)

# %%
modelo.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_4 (InputLayer)        [(None, 32, 32, 3)]          0         []
#
#  zero_padding2d_7 (ZeroPadd  (None, 38, 38, 3)            0         ['input_4[0][0]']
#  ing2D)
#
#  conv1 (Conv2D)              (None, 16, 16, 64)           9472      ['zero_padding2d_7[0][0]']
#
#  bn_conv1 (BatchNormalizati  (None, 16, 16, 64)           256       ['conv1[0][0]']
#  on)
#
#  activation_98 (Activation)  (None, 16, 16, 64)           0         ['bn_conv1[0][0]']
#
#  max_pooling2d_29 (MaxPooli  (None, 7, 7, 64)             0         ['activation_98[0][0]']
#  ng2D)
#
#  res_2_conv_a (Conv2D)       (None, 7, 7, 64)             4160      ['max_pooling2d_29[0][0]']
#
#  max_pooling2d_30 (MaxPooli  (None, 3, 3, 64)             0         ['res_2_conv_a[0][0]']
#  ng2D)
#
# ...

# %%
adam = tf.keras.optimizers.Adam(learning_rate = 0.005, beta_1 = 0.9, beta_2 = 0.999, amsgrad = False)

# %%
modelo.compile(loss = "sparse_categorical_crossentropy", optimizer=adam, metrics=['accuracy'])

# %%
# Guardamos el mejor modelo con mejor error de validación
checkpointer = ModelCheckpoint(filepath ="edvardks_modelo.hdf5", verbose = 1, save_best_only = True)

# %%
history = modelo.fit(X_train, y_train, batch_size=16 ,epochs = 3, validation_data=(X_val,y_val), callbacks=[checkpointer])
# Out:
# Epoch 1/3
# 2500/2500 [==============================] - ETA: 0s - loss: 2.1186 - accuracy: 0.1889
# Epoch 1: val_loss did not improve from 2.01157
# 2500/2500 [==============================] - 174s 70ms/step - loss: 2.1186 - accuracy: 0.1889 - val_loss: 2.0445 - val_accuracy: 0.2030
# Epoch 2/3
# 2500/2500 [==============================] - ETA: 0s - loss: 2.0080 - accuracy: 0.2141
# Epoch 2: val_loss improved from 2.01157 to 1.83773, saving model to edvardks_modelo.hdf5
# C:\Users\Edwar\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# ...

# %% [markdown]
# # Evaluando el modelo

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
history.history
# Out:
# {'loss': [2.1185901165008545, 2.008026599884033, 1.9656083583831787],
#  'accuracy': [0.18885000050067902, 0.21410000324249268, 0.24220000207424164],
#  'val_loss': [2.0444681644439697, 1.8377302885055542, 1.8503451347351074],
#  'val_accuracy': [0.2029999941587448, 0.266400009393692, 0.2687999904155731]}

# %%
# Visualizar La función de Perdida gracias a nuestro datos de validación

plt.plot(history.history['loss'], label="loss")
plt.plot(history.history['val_loss'], label="Validación")
# plt.plot(history.history['accuracy'], label="accuracy")
# plt.plot(history.history['val_accuracy'], label="val_accuracy")
plt.ylabel('Función de perdida')
plt.xlabel('Época')
plt.legend(loc="upper right")

# %%
perdida_test, acierto_test = modelo.evaluate(X_test, y_test)
print('Nuestro modelo acierta en el conjunto de evaluación en un porcentaje de:', acierto_test * 100, "%.")
# Out:
# 313/313 [==============================] - 4s 12ms/step - loss: 1.8404 - accuracy: 0.2756
# Nuestro modelo acierta en el conjunto de evaluación en un porcentaje de: 27.559998631477356 %.

# %%
# métricas de clasificación
y_pred = modelo.predict(X_test)
y_pred[0]
# Out:
# 313/313 [==============================] - 4s 12ms/step
# array([0.03699699, 0.07061393, 0.09348608, 0.144318  , 0.07373212,
#        0.1627385 , 0.11672666, 0.17684235, 0.0324789 , 0.09206652],
#       dtype=float32)

# %%
y_test
# Out:
# array([3, 8, 8, ..., 5, 1, 7], dtype=int64)

# %%
y_pred_labels = np.argmax(y_pred, axis=1)

# %%
conf_matrix = confusion_matrix(y_true=y_test, y_pred=y_pred_labels)

# %%
# Calcula la matriz de confusión
print("Matriz de Confusión:")
print(conf_matrix)
# Out:
# Matriz de Confusión:
# [[415 217  57   0   0  10  24  58 168  51]
#  [ 26 630   1   0   0   4  15  34  37 253]
#  [123  79 122   0   0  36 410 171  13  46]
#  [ 46  99  64   0   0 123 320 299   3  46]
#  [ 91  54  98   0   0  26 573 126   9  23]
#  [ 36  56  54   0   0 213 319 280   1  41]
#  [ 34  60  70   0   0  28 603 165   5  35]
#  [ 35 156  33   0   0 115 208 368   3  82]
#  [310 363  27   0   0   4  10  43 178  65]
#  [ 29 624  12   0   0   6  16  45  41 227]]

# %%
plt.figure(figsize = (10, 10))
sns.heatmap(conf_matrix, annot = True, cbar = False)
# Out:
# <Axes: >

# %%
# Calcula el informe de clasificación
class_report = classification_report(y_true=y_test, y_pred=y_pred_labels)
print("Informe de Clasificación:")
print(class_report)
# Out:
# Informe de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.36      0.41      0.39      1000
#            1       0.27      0.63      0.38      1000
#            2       0.23      0.12      0.16      1000
#            3       0.00      0.00      0.00      1000
#            4       0.00      0.00      0.00      1000
#            5       0.38      0.21      0.27      1000
#            6       0.24      0.60      0.34      1000
#            7       0.23      0.37      0.28      1000
#            8       0.39      0.18      0.24      1000
#            9       0.26      0.23      0.24      1000
#
#     accuracy                           0.28     10000
#    macro avg       0.24      0.28      0.23     10000
# weighted avg       0.24      0.28      0.23     10000
# ...

# %%
label_to_text = {0:'Avión', 1:'Automóvil', 2:'Pájaros', 3:'Gatos', 4: 'Ciervos', 5:'Perros', 6:'Ranas', 7:'Caballos', 8:'Barcos', 9: 'Camiones'}

# %%
fig = plt.figure(figsize=(20, 20))

for i in range(16):
    fig.add_subplot(4, 4, i + 1)
    plt.imshow(X_test[i],cmap = 'gray')
    plt.title('Predicción = {}\n Verdadera = {}'.format(label_to_text[y_pred_labels[i]], label_to_text[y_test[i]]))
    plt.show

# %% [markdown]
# # Reflexión

# %% [markdown]
# Visto los resultados del modelo, se puede mejorar añadiendo más capas para nuestro modelo, y sobretodo, ampliando el batchsize, y epochs. Esto proporcionará a nuestro modelo más espacio en el tiempo para que entrene.

# %% [markdown]
# Mi modelo, ya ha dedicado mucho tiempo de entrenaiento, y en comparación los resultados tampoco son muy malos, ni muy buenos, seguiría entrenando otros modelos, para ver si consigo, al jugar con dichos paramentros, una mejor puntuación y la curva de la función de perdida mejorarla.

# %% [markdown]
# De echo quiero añadir que he estado probando diferentes parametros duarnte el exámen sin entregarlo. Así entregar el mejor modelo posible en este exámen

# %% [markdown]
# Con el cuarto modelo que entreno observo que el accuracy tampoco sube mucho, habiendo subido las epochs y bajado el batch_size, entonces voy ha dejarlo cómo está. Comprendo que debería añadir más fases, en mi modelo, y de está manera el modelo evolucionaría con mejores resultados. Pero se me acaba el tiempo, y no puedo jugar más :((

# %% [markdown]
# ## Edvard Khachatryan Sahakyan
